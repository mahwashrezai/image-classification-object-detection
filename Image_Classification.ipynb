# %% [markdown]
# <a href="https://colab.research.google.com/github/mahwashrezai/image-classification-object-detection/blob/main/Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
from google.colab import files
import math
from PIL import Image

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1704c981-d20e-4996-b62b-ed23c413c29c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1704c981-d20e-4996-b62b-ed23c413c29c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(source=img_name, imgsz=768)
results = []

for img_name in uploaded.keys():

    r = model(
        img_name,
        classes=[15,16],   # cat and dog only
        conf=0.15,         # lower confidence threshold
        imgsz=640
    )

    results.append(r)
# Out:
# image 1/1 /content/images (5).jpeg: 768x768 1 person, 771.5ms
# Speed: 4.9ms preprocess, 771.5ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 768)
#
# image 1/1 /content/images (6).jpeg: 448x640 1 dog, 367.0ms
# Speed: 2.8ms preprocess, 367.0ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82d5c236-e856-459a-bd89-5f47d2e02d83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82d5c236-e856-459a-bd89-5f47d2e02d83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import math

images = []

for r in results:
    img = r[0].plot()
    images.append(img)

cols = 2
rows = math.ceil(len(images)/cols)

plt.figure(figsize=(12,6*rows))

for i,img in enumerate(images):

    plt.subplot(rows,cols,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5be796fd-3ffa-4bb7-9a59-4616a1e36ac0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5be796fd-3ffa-4bb7-9a59-4616a1e36ac0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model.predict(source=img_name, imgsz=768)
results = []

for img_name in uploaded.keys():

    r = model(
        img_name,
        classes=[15,16],   # cat and dog only
        conf=0.15,         # lower confidence threshold
        imgsz=640
    )

    results.append(r)
# Out:
# image 1/1 /content/images (6).jpeg: 512x768 1 dog, 528.2ms
# Speed: 5.5ms preprocess, 528.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 768)
#
# image 1/1 /content/images (3) (1).jpeg: 640x416 1 cat, 372.2ms
# Speed: 3.8ms preprocess, 372.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)

# %%
import matplotlib.pyplot as plt
import math

images = []

for r in results:
    img = r[0].plot()
    images.append(img)

cols = 2
rows = math.ceil(len(images)/cols)

plt.figure(figsize=(12,6*rows))

for i,img in enumerate(images):

    plt.subplot(rows,cols,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
uploaded = files.upload()

# %%
model.predict(source=img_name, imgsz=768)
results = []

for img_name in uploaded.keys():

    r = model(
        img_name,
        classes=[15,16],   # cat and dog only
        conf=0.15,         # lower confidence threshold
        imgsz=640
    )

    results.append(r)
# Out:
# image 1/1 /content/images (3).jpeg: 768x768 1 person, 1428.8ms
# Speed: 9.2ms preprocess, 1428.8ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 768)
#
# image 1/1 /content/Editorial_28_July_2025_Image_1 (1).jpg: 448x640 1 dog, 704.9ms
# Speed: 5.4ms preprocess, 704.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/images (4).jpeg: 448x640 2 cats, 404.5ms
# Speed: 6.6ms preprocess, 404.5ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/images (1) (2).jpeg: 480x640 1 cat, 1 dog, 401.4ms
# Speed: 2.9ms preprocess, 401.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/images (5).jpeg: 640x640 1 dog, 502.2ms
# Speed: 4.9ms preprocess, 502.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
import math

images = []

for r in results:
    img = r[0].plot()
    images.append(img)

cols = 2
rows = math.ceil(len(images)/cols)

plt.figure(figsize=(12,6*rows))

for i,img in enumerate(images):

    plt.subplot(rows,cols,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()
plt.show()
